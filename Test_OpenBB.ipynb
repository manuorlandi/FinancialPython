# %%
from openbb_terminal.sdk import openbb
import pandas as pd
# %matplotlib inline

# %%
economic_calendar = openbb.economy.events()

economic_calendar
# Out:
#    Time (GMT)    Country                             Event actual consensus  \
# 0         24H      Japan              Household Confidence   30.3         -
# 1         24H  Singapore                      Retail Sales   6.2%         -
# 2         24H  Singapore                      Retail Sales  -3.7%         -
# 3       02:00    Germany                    German Exports  -0.3%      0.2%
# 4       02:00    Germany                    German Imports  -3.3%     -0.5%
# ..        ...        ...                               ...    ...       ...
# 56      18:30      Japan             Average Cash Earnings      -         -
# 57      18:30      Japan  Overall wage income of employees      -         -
# 58      18:30      Japan                      Overtime Pay      -         -
# 59      19:30      Japan                      Services PMI      -      51.7
# 60      22:35      Japan               30-Year JGB Auction      -         -
#
#    previous        Date
# 0      28.6  2023-01-05
# ...

# %%
openbb.econometrics.about()

# %%
economic_calendar = openbb.economy.events()
economic_calendar.set_index(keys = ['Time (GMT)'], append = True, inplace = True)
events = economic_calendar.filter(like = '2:00', axis = 0)

events
# Out:
#               Country                 Event actual consensus previous  \
#   Time (GMT)
# 3 02:00       Germany        German Exports  -0.3%      0.2%     0.8%
# 4 02:00       Germany        German Imports  -3.3%     -0.5%    -2.4%
# 5 02:00       Germany  German Trade Balance  10.8B      7.5B     6.9B
#
#                     Date
#   Time (GMT)
# 3 02:00       2023-01-05
# 4 02:00       2023-01-05
# 5 02:00       2023-01-05

# %%
openbb.stocks.ca.screener(similar = ['AAPL', 'NFLX', 'META', 'AMZN', 'MSFT', 'GOOGL', 'DIS', 'TSLA'], data_type = 'valuation')
# Out:
#   Ticker    Market Cap    P/E  Fwd P/E   PEG   P/S    P/B    P/C   P/FCF  \
# 0   AAPL  2.005200e+12  20.71    18.67  2.37  5.09  39.99  41.51   20.76
# 1   AMZN  8.704300e+11  78.54    51.85  3.02  1.73   6.31  14.84     NaN
# 2    DIS  1.683100e+11  52.62    17.34  2.22  2.03   1.81  12.99  108.52
# 3  GOOGL  1.145900e+12  17.83    16.94  1.99  4.06   4.52   9.86   18.32
# 4   META  3.375000e+11  12.15    16.04   NaN  2.86   2.75   8.08   12.83
# 5   MSFT  1.716290e+12  24.69    20.48  1.90  8.45   9.84  16.00   38.32
# 6   NFLX  1.359400e+11  29.17    29.51  5.02  4.32   6.71  22.24  189.59
# 7   TSLA  3.548900e+11  35.01    21.35  0.88  4.74   8.97  16.81   22.15
#
#    EPS this Y  EPS next Y  EPS past 5Y  EPS next 5Y  Sales past 5Y   Price  \
# 0       0.089      0.0909        0.216       0.0873          0.115  125.94
# 1       0.549      0.7848        0.676       0.2600          0.281   83.87
# 2       1.707      0.2847       -0.280       0.2375          0.039   91.99
# ...

# %%
spy_daily = openbb.stocks.load(
        symbol = 'SPY',
        start_date = '1993-11-01',
        monthly = True)

openbb.stocks.candle(
    data = spy_daily,
    asset_type = 'SPY - Monthly Chart from November, 1993',
    symbol = ''
)
# Out:
# Loading Daily data for SPY with starting period 1993-11-01.

# %%
openbb.crypto.disc.coins_for_given_exchange()
# Out:
# [{'base': 'BUSD',
#   'target': 'USDT',
#   'market': {'name': 'Binance',
#    'identifier': 'binance',
#    'has_trading_incentive': False},
#   'last': 1.0003,
#   'volume': 518792196.9012296,
#   'converted_last': {'btc': 5.941e-05, 'eth': 0.0007989, 'usd': 1.0},
#   'converted_volume': {'btc': 30823, 'eth': 414465, 'usd': 519047673},
#   'trust_score': 'green',
#   'bid_ask_spread_percentage': 0.019996,
#   'timestamp': '2023-01-05T19:33:11+00:00',
#   'last_traded_at': '2023-01-05T19:33:11+00:00',
#   'last_fetch_at': '2023-01-05T19:33:11+00:00',
#   'is_anomaly': False,
#   'is_stale': False,
#   'trade_url': 'https://www.binance.com/en/trade/BUSD_USDT?ref=37754157',
#   'token_info_url': None,
#   'coin_id': 'binance-usd',
#   'target_coin_id': 'tether'},
#  {'base': 'BTC',
#   'target': 'USDT',
#   'market': {'name': 'Binance',
#    'identifier': 'binance',
#    'has_trading_incentive': False},
#   'last': 16841.18,
#   'volume': 167082.9260650183,
# ...

# %%
openbb.crypto.dd.exchanges()
# Out:
# ['aax',
#  'alpaca',
#  'ascendex',
#  'bequant',
#  'bibox',
#  'bigone',
#  'binance',
#  'binancecoinm',
#  'binanceus',
#  'binanceusdm',
#  'bit2c',
#  'bitbank',
#  'bitbay',
#  'bitbns',
#  'bitcoincom',
#  'bitfinex',
#  'bitfinex2',
#  'bitflyer',
#  'bitforex',
#  'bitget',
#  'bithumb',
#  'bitmart',
#  'bitmex',
#  'bitopro',
#  'bitpanda',
#  'bitrue',
#  'bitso',
#  'bitstamp',
#  'bitstamp1',
#  'bittrex',
#  'bitvavo',
#  'bkex',
#  'bl3p',
#  'blockchaincom',
#  'btcalpha',
#  'btcbox',
#  'btcex',
#  'btcmarkets',
#  'btctradeua',
#  'btcturk',
#  'buda',
#  'bw',
#  'bybit',
#  'bytetrade',
#  'cex',
#  'coinbase',
#  'coinbaseprime',
#  'coinbasepro',
#  'coincheck',
#  'coinex',
#  'coinfalcon',
#  'coinmate',
#  'coinone',
#  'coinspot',
#  'crex24',
#  'cryptocom',
#  'currencycom',
#  'delta',
#  'deribit',
#  'digifinex',
#  'eqonex',
#  'exmo',
#  'flowbtc',
#  'fmfwio',
#  'ftx',
#  'ftxus',
#  'gate',
#  'gateio',
#  'gemini',
#  'hitbtc',
#  'hitbtc3',
# ...

# %%
openbb.crypto.disc.coins().head(5)
# Out:
#                 id symbol           name  \
# 172             0x    zrx             0x
# 99         zilliqa    zil        Zilliqa
# 194        zencash    zen        Horizen
# 63           zcash    zec          Zcash
# 146  yearn-finance    yfi  yearn.finance
#
#                                                  image  current_price  \
# 172  https://assets.coingecko.com/coins/images/863/...       0.158451
# 99   https://assets.coingecko.com/coins/images/2687...       0.016885
# 194  https://assets.coingecko.com/coins/images/691/...       8.880000
# 63   https://assets.coingecko.com/coins/images/486/...      40.170000
# 146  https://assets.coingecko.com/coins/images/1184...    5413.220000
#
#      market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 172   134277404              174              158440152.0     9711456.0
# 99    287558043              100              354630673.0    16108180.0
# 194   117628190              195              186783856.0     5574727.0
# ...

# %%
categories = openbb.crypto.disc.categories_keys()
categories
# Out:
# ['aave-tokens',
#  'analytics',
#  'arbitrum-ecosystem',
#  'artificial-intelligence',
#  'asset-backed-tokens',
#  'asset-manager',
#  'augmented-reality',
#  'automated-market-maker-amm',
#  'avalanche-ecosystem',
#  'axie-infinity',
#  'big-data',
#  'binance-launchpool',
#  'binance-smart-chain',
#  'business-platform',
#  'business-services',
#  'cardano-ecosystem',
#  'celo-ecosystem',
#  'centralized-exchange-token-cex',
#  'charity',
#  'cny-stablecoin',
#  'collectibles',
#  'communication',
#  'compound-tokens',
#  'cosmos-ecosystem',
#  'cryptocurrency',
#  'daomaker-ecosystem',
#  'decentralized-exchange',
#  'decentralized-finance-defi',
#  'defi-index',
#  'decentralized-derivatives',
#  'education',
#  'energy',
#  'entertainment',
#  'etf',
#  'eth-2-0-staking',
#  'eur-stablecoin',
#  'exchange-based-tokens',
#  'fan-token',
#  'fantom-ecosystem',
#  'finance-banking',
#  'fractionalized-nft',
#  'gambling',
#  'gaming',
#  'gbp-stablecoin',
#  'gig-economy',
# ...

# %%
df = openbb.crypto.disc.coins(sortby = 'market_cap').head(50)
df

# %%
openbb.crypto.disc.trending()
# Out:
#             Symbol            Name  market_cap Cap Rank
# 0             bonk            Bonk                  253
# 1         fetch-ai        Fetch.ai                  197
# 2             gala            GALA                  146
# 3  oraichain-token       Oraichain                  836
# 4              tap             Tap                  859
# 5           solana          Solana                   17
# 6   dejitaru-tsuka  Dejitaru Tsuka                  343
# 7            aptos           Aptos                   70

# %%
display(openbb.crypto.disc.losers().head(3))
display(openbb.crypto.disc.losers(interval = '14d').head(3))
openbb.crypto.disc.losers(interval = '1y').head(3)
# Out:
#    Symbol                 Name  Price [$]  Market Cap  Market Cap Rank  \
# 29    qnt                Quant     113.92  1658865651               30
# 31    ape              ApeCoin       4.03  1457886165               32
# 45   egld  MultiversX (Elrond)      34.16   823034930               46
#
#     Volume [$]  Change 1h [%]
# 29    34517804      -0.643876
# 31   106060592      -0.157585
# 45    17637513      -0.126028
#    Symbol     Name  Price [$]  Market Cap  Market Cap Rank  Volume [$]  \
# 21    ton  Toncoin   2.180000  3211253449               22    30693415
# 49     ht    Huobi   4.580000   744587212               50    21868689
# 40   hbar   Hedera   0.038579   970290461               41    20496379
#
#     Change 14d [%]
# 21      -13.220451
# 49      -12.959558
# 40       -9.920747
#    Symbol                Name  Price [$]  Market Cap  Market Cap Rank  \
# 41   lunc  Terra Luna Classic   0.000154   929368519               42
# ...

# %%
help(openbb.econometrics)
# Out:
# Help on Breadcrumb in module openbb_terminal.core.library.breadcrumb:
#
# <openbb_terminal.core.library.breadcrumb.Breadcrumb object>
#     ECONOMETRICS Menu
#
#     The SDK commands of the the menu:
#             <openbb>.econometrics.re
#             <openbb>.econometrics.load
#             <openbb>.econometrics.panel
#             <openbb>.econometrics.panel_chart
#             <openbb>.econometrics.bols
#             <openbb>.econometrics.bgod
#             <openbb>.econometrics.bgod_chart
#             <openbb>.econometrics.options
#             <openbb>.econometrics.options_chart
#             <openbb>.econometrics.pols
#             <openbb>.econometrics.bpag
#             <openbb>.econometrics.bpag_chart
#             <openbb>.econometrics.dwat
#             <openbb>.econometrics.dwat_chart
#             <openbb>.econometrics.ols
#             <openbb>.econometrics.coint
#             <openbb>.econometrics.coint_chart
#             <openbb>.econometrics.get_regression_data
# ...

# %%
openbb.crypto.candle(symbol="eth")
openbb.crypto.candle(symbol="btc")
# Out:
#                 Open      High       Low     Close         Volume
# date
# 2020-01-01   7195.24   7255.00   7175.15   7200.85   16792.388165
# 2020-01-02   7200.77   7212.50   6924.74   6965.71   31951.483932
# 2020-01-03   6965.49   7405.00   6871.04   7344.96   68428.500451
# 2020-01-04   7345.00   7404.00   7272.21   7354.11   29987.974977
# 2020-01-05   7354.19   7495.00   7318.00   7358.75   38331.085604
# ...              ...       ...       ...       ...            ...
# 2023-01-01  16541.77  16628.00  16499.01  16616.75   96925.413740
# 2023-01-02  16617.17  16799.23  16548.70  16672.87  121888.571910
# 2023-01-03  16672.78  16778.40  16605.28  16675.18  159541.537330
# 2023-01-04  16675.65  16991.87  16652.66  16850.36  220362.188620
# 2023-01-05  16850.36  16879.82  16753.00  16864.43  141441.254650
#
# [1101 rows x 5 columns]

# %%
from openbb_terminal.sdk import openbb
openbb.keys.mykeys(show = True)
# Out:
#                    Key
# API
# ETHPLORER_KEY  freekey

# %%
openbb.keys.binance(
key='NWsrhdt4IlgVqhsmG9Y5HhKfmymvUs7JoW51ORpwF5Bhmey0bHTRKbi2iiHgc8Ey',
secret='T5wwjgIkmihqnEO4qscDvNNNX9eoWoYIx7FHKkVn0vRFaHOtmIJzwMSaHiuayxbX',
persist=True)
# Out:
# 'defined, test failed'

# %%
openbb.crypto.dd.exchanges()
# Out:
# ['aax',
#  'alpaca',
#  'ascendex',
#  'bequant',
#  'bibox',
#  'bigone',
#  'binance',
#  'binancecoinm',
#  'binanceus',
#  'binanceusdm',
#  'bit2c',
#  'bitbank',
#  'bitbay',
#  'bitbns',
#  'bitcoincom',
#  'bitfinex',
#  'bitfinex2',
#  'bitflyer',
#  'bitforex',
#  'bitget',
#  'bithumb',
#  'bitmart',
#  'bitmex',
#  'bitopro',
#  'bitpanda',
#  'bitrue',
#  'bitso',
#  'bitstamp',
#  'bitstamp1',
#  'bittrex',
#  'bitvavo',
#  'bkex',
#  'bl3p',
#  'blockchaincom',
#  'btcalpha',
#  'btcbox',
#  'btcex',
#  'btcmarkets',
#  'btctradeua',
#  'btcturk',
#  'buda',
#  'bw',
#  'bybit',
#  'bytetrade',
#  'cex',
#  'coinbase',
#  'coinbaseprime',
#  'coinbasepro',
#  'coincheck',
#  'coinex',
#  'coinfalcon',
#  'coinmate',
#  'coinone',
#  'coinspot',
#  'crex24',
#  'cryptocom',
#  'currencycom',
#  'delta',
#  'deribit',
#  'digifinex',
#  'eqonex',
#  'exmo',
#  'flowbtc',
#  'fmfwio',
#  'ftx',
#  'ftxus',
#  'gate',
#  'gateio',
#  'gemini',
#  'hitbtc',
#  'hitbtc3',
# ...

# %%
openbb.crypto.load(symbol='btc', source='CCXT', exchange='binance', start_date='2012-12-12')
# Out:
#                 Open      High       Low     Close         Volume
# date
# 2017-08-17   4261.48   4485.39   4200.74   4285.08     795.150377
# 2017-08-18   4285.08   4371.52   3938.77   4108.37    1199.888264
# 2017-08-19   4108.37   4184.69   3850.00   4139.98     381.309763
# 2017-08-20   4120.98   4211.08   4032.62   4086.29     467.083022
# 2017-08-21   4069.13   4119.62   3911.79   4016.00     691.743060
# ...              ...       ...       ...       ...            ...
# 2023-01-03  16672.78  16778.40  16605.28  16675.18  159541.537330
# 2023-01-04  16675.65  16991.87  16652.66  16850.36  220362.188620
# 2023-01-05  16850.36  16879.82  16753.00  16831.85  163473.566410
# 2023-01-06  16831.85  17041.00  16679.00  16950.65  207401.284150
# 2023-01-07  16950.31  16981.91  16908.00  16941.24   94555.440830
#
# [1970 rows x 5 columns]

# %%
es = openbb.stocks.load("QQQ")

openbb.ta.ma_chart(
    data = es['Adj Close'],
    symbol = 'QQQ Futures',
    ma_type = 'SMA',
    window = [21, 150])
# Out:
# Loading Daily data for QQQ with starting period 2020-01-03.

# %%
ticker = 'QQQ'
start = '2000-01-01'
data_df: pd.DataFrame = openbb.stocks.load(f"{ticker}", start_date = f"{start}", monthly = True)

openbb.ta.donchian_chart(data_df)
# Out:
# Loading Daily data for QQQ with starting period 2000-01-01.

# %%
ope
# Out:
#                 Open      High       Low     Close         Volume
# date
# 2020-01-04   7345.00   7404.00   7272.21   7354.11   29987.974977
# 2020-01-05   7354.19   7495.00   7318.00   7358.75   38331.085604
# 2020-01-06   7357.64   7795.34   7346.76   7758.00   54635.695316
# 2020-01-07   7758.90   8207.68   7723.71   8145.28   91171.684661
# 2020-01-08   8145.92   8455.00   7870.00   8055.98  112622.642640
# ...              ...       ...       ...       ...            ...
# 2023-01-04  16675.65  16991.87  16652.66  16850.36  220362.188620
# 2023-01-05  16850.36  16879.82  16753.00  16831.85  163473.566410
# 2023-01-06  16831.85  17041.00  16679.00  16950.65  207401.284150
# 2023-01-07  16950.31  16981.91  16908.00  16943.57  104526.568800
# 2023-01-08  16943.83  17022.08  16911.00  16948.23   88612.417630
#
# [1101 rows x 5 columns]
